# %%
l = [2]

type(l)
# Out:
# list

# %% [markdown]
# ### List Methods

# %%
fruits = ['Apple', 'banana', 'kiwi']

# Add item at the end
fruits.append("Guava")

# insert at the index
fruits.insert(1, 'watermelon')
fruits.remove("watermelon")

print(fruits)
# Out:
# ['Apple', 'watermilon', 'banana', 'kiwi', 'Guawa']
# None

# %%
# remove value
# fruits.remove("banana")

# remove last item and return 
popped_item = fruits.pop()
print(popped_item)
# Out:
# Guawa

# %%
# return index of value
fruits.index('banana')

# return count of values
fruits.count('banana')
# Out:
# 1

# %%
# sort the list
fruits.sort()

# revers the list
fruits.reverse()
print(fruits)
# Out:
# ['watermilon', 'kiwi', 'banana', 'Apple']

# %%
# remove all items
fruits.clear()

# %%
# slicing 
numbers = [1, 2, 3, 4 ,5, 6, 7, 8]
print(numbers[1:5]) # from index 1 to 4 ( 5 excluded )
print(numbers[1:]) # from index 1 to end
print(numbers[::2]) # :: means step size -> it will step 2 items and print
print(numbers[::-1]) # will revers and make step
# Out:
# [2, 3, 4, 5]
# [2, 3, 4, 5, 6, 7, 8]
# [1, 3, 5, 7]
# [8, 7, 6, 5, 4, 3, 2, 1]

# %%
# iterating on list
for number in numbers:
    print(number)

# if you want index you can use enumerate
for index, number in enumerate(number):
    print(index, number)
# Out:
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 6
#       3     print(number)
#       5 # if you want index you can use enumerate
# ----> 6 for index, number in enumerate(number):
#       7     print(index, number)
#
# TypeError: 'int' object is not iterable

# %%
# List comprehension

numbers = [1, 2, 3, 4]
chars = ['a', 'b', 'c', 'd']

square = [ x**2 for x in numbers]
print(square)

even = [ x for x in numbers if x%2==0]
print(even)

pairs = [[i,j] for i in numbers for j in chars]
print(pairs)

words = ['qqqq', 'wed']

lengths_of_words = [len(i) for i in words]
print(lengths_of_words)
# Out:
# [1, 4, 9, 16]
# [2, 4]
# [[1, 'a'], [1, 'b'], [1, 'c'], [1, 'd'], [2, 'a'], [2, 'b'], [2, 'c'], [2, 'd'], [3, 'a'], [3, 'b'], [3, 'c'], [3, 'd'], [4, 'a'], [4, 'b'], [4, 'c'], [4, 'd']]
# [4, 3]
