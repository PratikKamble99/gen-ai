# %% [markdown]
# ### Dictionary contains key value pairs
# #### it is mutable data structure

# %%
dict1 = {"name":'pratik', "age":20}
print(type(dict1))
print(dict1)
# Out:
# <class 'dict'>
# {'name': 'pratik', 'age': 20}

# %%
# get differnt behavior
students = {"name":'pratik', 'age': 20, "name": "hjska"} # second time name will override fist name 'pratik'
print(students)

# Accessing value
print(students["name"]) # If not present value code will crash
print(students.get('name')) # using get method  // safe way to access values from dict
print(students.get('first_name', 'Not available')) # if key is not present then it returns provided text as second parameter by default None
# Out:
# {'name': 'hjska', 'age': 20}
# hjska
# hjska
# Not available

# %%
# modifying dictionary

students = {'name': 'pratik', 'age': 20}

# insert
students['grade'] = '12th'


# update 
students['age'] = 25
print(students)

# delete
del students['grade']
print(students)
# Out:
# {'name': 'pratik', 'age': 25, 'grade': '12th'}
# {'name': 'pratik', 'age': 25}

# %%
# dictionary methods
keys = students.keys()
print(keys)

values = students.values()
print(values)

key_values = students.items()
print(key_values)
# Out:
# dict_keys(['name', 'age'])
# dict_values(['pratik', 25])
# dict_items([('name', 'pratik'), ('age', 25)])

# %%
# deep copy
deep = students

# shallow copy
copy = students.copy()

# %%
# Iterating over dictionaries
students = {
    "student_1":{
        "name": "pratik",
        "age": 20
    },
    "student_2":{
        'name': 'Pratik_2',
        'age': 28
    }
}

for key in students.keys():
    print(key)

print('-----------')

for value in students.values():
    print(value)

print('-----------')

for key, student_info in students.items():
    print(f"{key}")
    for key_2,student in student_info.items():
        print(f"{key_2}:{student}")
# Out:
# student_1
# student_2
# -----------
# {'name': 'pratik', 'age': 20}
# {'name': 'Pratik_2', 'age': 28}
# -----------
# student_1
# name:pratik
# age:20
# student_2
# name:Pratik_2
# age:28

# %%
# Dictionary comprehension
squares = {x:x*x for x in range(1, 10)}
print(squares)

even = {x:x for x in range(1, 10) if x%2!=0}
print(even)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}
# {1: 1, 3: 3, 5: 5, 7: 7, 9: 9}
