# %% [markdown]
# ### TF-IDF

# %%
import pandas as pd

# import os
# print(os.listdir('./data'))
messages = pd.read_csv('./data/large_spam_collection.csv',)
messages
# Out:
#    label                                            message
# 0   spam                Lowest prices guaranteed. Shop now.
# 1   spam           Act fast! Double your income in 30 days.
# 2   spam   Get cheap loans with no credit check. Apply now!
# 3    ham              Happy Birthday! Have a wonderful day.
# 4    ham           Hey, are we still on for dinner tonight?
# ..   ...                                                ...
# 95  spam   Get cheap loans with no credit check. Apply now!
# 96  spam  URGENT! Your account has been suspended. Verif...
# 97   ham           Hey, are we still on for dinner tonight?
# 98  spam           Act fast! Double your income in 30 days.
# 99  spam   Exclusive deal just for you. Limited time offer.
#
# [100 rows x 2 columns]

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

wordlemmatize = WordNetLemmatizer()

# %%
corpus = []

for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', messages['message'][i])
    review = review.lower()
    review = review.split()
    review = [wordlemmatize.lemmatize(word) for word in review if word not in stopwords.words('english')]
    review = " ".join(review)
    corpus.append(review)

print(corpus)
# Out:
# ['lowest price guaranteed shop', 'act fast double income day', 'get cheap loan credit check apply', 'happy birthday wonderful day', 'hey still dinner tonight', 'pick pm', 'happy birthday wonderful day', 'urgent account suspended verify immediately', 'let catch weekend', 'good luck exam tomorrow', 'let catch weekend', 'pick pm', 'urgent account suspended verify immediately', 'let catch weekend', 'congratulation gift card claim', 'call reach home', 'get cheap loan credit check apply', 'subscription expiring renew immediately', 'send note class', 'call reach home', 'lowest price guaranteed shop', 'urgent account suspended verify immediately', 'hey still dinner tonight', 'good luck exam tomorrow', 'act fast double income day', 'forget bring id card', 'pick pm', 'subscription expiring renew immediately', 'see gym later', 'act fast double income day', 'good luck exam tomorrow', 'forget bring id card', 'congratulation gift card claim', 'time movie start', 'win free vacation paris click', 'pick pm', 'urgent account suspended verify immediately', 'urgent account suspended verify immediately', 'good luck exam tomorrow', 'see gym later', 'send note class', 'pick pm', 'let catch weekend', 'lowest price guaranteed shop', 'hey still dinner tonight', 'time movie start', 'exclusive deal limited time offer', 'hey still dinner tonight', 'lowest price guaranteed shop', 'hey still dinner tonight', 'let catch weekend', 'call reach home', 'see gym later', 'see gym later', 'call reach home', 'congratulation gift card claim', 'see gym later', 'exclusive deal limited time offer', 'good luck exam tomorrow', 'lowest price guaranteed shop', 'get cheap loan credit check apply', 'selected cash prize call', 'subscription expiring renew immediately', 'happy birthday wonderful day', 'urgent account suspended verify immediately', 'subscription expiring renew immediately', 'call reach home', 'exclusive deal limited time offer', 'exclusive deal limited time offer', 'get cheap loan credit check apply', 'exclusive deal limited time offer', 'time movie start', 'congratulation gift card claim', 'pick pm', 'cheap medicine available online order today', 'urgent account suspended verify immediately', 'selected cash prize call', 'time movie start', 'selected cash prize call', 'get cheap loan credit check apply', 'congratulation gift card claim', 'act fast double income day', 'hey still dinner tonight', 'forget bring id card', 'call reach home', 'win free vacation paris click', 'send note class', 'time movie start', 'call reach home', 'urgent account suspended verify immediately', 'selected cash prize call', 'get cheap loan credit check apply', 'cheap medicine available online order today', 'selected cash prize call', 'good luck exam tomorrow', 'get cheap loan credit check apply', 'urgent account suspended verify immediately', 'hey still dinner tonight', 'act fast double income day', 'exclusive deal limited time offer']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
X = tfidf.fit_transform(corpus)
tfidf.get_feature_names_out()

print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 403 stored elements and shape (100, 75)>
#   Coords	Values
#   (0, 42)	0.5
#   (0, 53)	0.5
#   (0, 30)	0.5
#   (0, 60)	0.5
#   (1, 1)	0.4564759932512685
#   (1, 24)	0.4564759932512685
#   (1, 20)	0.4564759932512685
#   (1, 37)	0.4564759932512685
#   (1, 17)	0.40806699246701095
#   (2, 27)	0.41247164955203275
#   (2, 10)	0.38643976449005013
#   (2, 41)	0.41247164955203275
#   (2, 16)	0.41247164955203275
#   (2, 11)	0.41247164955203275
#   (2, 2)	0.41247164955203275
#   (3, 17)	0.42286275386831423
#   (3, 32)	0.5231911987635449
#   (3, 4)	0.5231911987635449
#   (3, 74)	0.5231911987635449
#   (4, 33)	0.5
#   (4, 62)	0.5
#   (4, 19)	0.5
#   (4, 68)	0.5
#   (5, 51)	0.7071067811865476
#   (5, 52)	0.7071067811865476
#   :	:
#   (95, 27)	0.41247164955203275
#   (95, 10)	0.38643976449005013
#   (95, 41)	0.41247164955203275
#   (95, 16)	0.41247164955203275
#   (95, 11)	0.41247164955203275
#   (95, 2)	0.41247164955203275
#   (96, 69)	0.45609510264366426
#   (96, 0)	0.45609510264366426
#   (96, 64)	0.45609510264366426
#   (96, 71)	0.45609510264366426
#   (96, 36)	0.4097670428156243
#   (97, 33)	0.5
#   (97, 62)	0.5
#   (97, 19)	0.5
#   (97, 68)	0.5
#   (98, 1)	0.4564759932512685
#   (98, 24)	0.4564759932512685
#   (98, 20)	0.4564759932512685
#   (98, 37)	0.4564759932512685
#   (98, 17)	0.40806699246701095
#   (99, 65)	0.3923490118239191
#   (99, 22)	0.45990821174468993
#   (99, 18)	0.45990821174468993
#   (99, 40)	0.45990821174468993
#   (99, 47)	0.45990821174468993
